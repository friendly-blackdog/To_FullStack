# %% [markdown]
# ## DNN Function Approximation 신경망 파라미터 변경

# %% [markdown]
# #### Package Import

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### Activation Function

# %%
def activation_1(n):
    return 1/(1+np.exp(-n))

def activation_2(n):
    return n

# %% [markdown]
# #### 가중치와 편향

# %%
p = np.arange(-2, 2, 0.01)
p = p[np.newaxis, : ] # 입력 데이터는 (1, 400) 형태

# %% [markdown]
# #### Q. 첫번째 계층의 편향 b1의 두번째 편향을 변경해 보시오.

# %%
W1 = np.array([[10],[10]],float)
b1 = np.array([[-10],[10]],float)
W2 = np.array([1,1],float)
b2 = np.array([[0]], float)

#your code
    
plt.axis([-2, 2, -1, 3])
plt.show()

# %% [markdown]
# #### Q. W2의 첫번째 가중치 변경해 보시오.

# %%
W1 = np.array([[10],[10]],float)
b1 = np.array([[-10],[10]],float)
W2 = np.array([1,1],float)
b2 = np.array([[0]], float)

# your code
    
plt.axis([-2, 2, -1, 3])
plt.show()

# %% [markdown]
# #### Q. W2의 두번째 가중치 변경해 보시오.

# %%
W1 = np.array([[10],[10]],float)
b1 = np.array([[-10],[10]],float)
W2 = np.array([1,1],float)
b2 = np.array([[0]], float)

# your code
    
plt.axis([-2, 2, -1, 3])
plt.show()

# %% [markdown]
# #### Q. 두번째 계층의 편향 b2 변경해 보시오.

# %%
W1 = np.array([[10],[10]],float)
b1 = np.array([[-10],[10]],float)
W2 = np.array([1,1],float)
b2 = np.array([[0]], float)

# your code
    
plt.axis([-2, 2, -1, 3])
plt.show()
